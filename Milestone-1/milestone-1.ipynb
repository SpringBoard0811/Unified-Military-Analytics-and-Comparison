# %% [markdown]
# # Unified Military Analytics And Comparison Dashboard-DV

# %% [markdown]
# ##### Identified the core metrics required for military strength analysis as mentioned in the document. These metrics cover human, financial, land, air, and sea dimensions.

# %% [markdown]
# ##### Define raw data schema we defined a raw data schema to structure the scraped data consistently.
#
# ##### 1.Each row represents one country 2.Columns represent selected metrics 3.Stored initially in raw form without cleaning
# ##### Scrape data from one country page correctly. Implemented live scraping using the country detail page of GlobalFirepower.
#
# ##### This step creates a local folder named data to store all the scraped country CSV files.

# %%
import os
os.makedirs("data", exist_ok=True)

# %%
pip install lxml
# Out:
# Requirement already satisfied: lxml in C:\Users\pradeep_\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (6.0.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
soup = BeautifulSoup(response.text, "html.parser")

# %% [markdown]
# ##### This step sends a request to the Global Firepower website and extracts India's military data including power index and detailed metrics.

# %%
import os
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd

os.makedirs("data", exist_ok=True)

url = "https://www.globalfirepower.com/country-military-strength-detail.php?country_id=india"
response = requests.get(url, timeout=15)
response.raise_for_status()

# Use built-in parser if lxml not installed
soup = BeautifulSoup(response.text, "html.parser")
data = {}

title = soup.find("h1")
if title:
    data["country"] = title.get_text(strip=True)

overview_text = soup.find("span", class_="textNormal")
if overview_text:
    text = overview_text.get_text(" ", strip=True)
    rank_match = re.search(r"ranked\s#(\d+)", text)
    score_match = re.search(r"score of\s([\d.]+)", text)

    data["power_index_rank"] = rank_match.group(1) if rank_match else None
    data["power_index_score"] = score_match.group(1) if score_match else None

metric_blocks = soup.find_all("div", class_="specsGenContainers")
for block in metric_blocks:
    label = block.find("span", class_="textLarge")
    value = block.find("span", class_="textWhite")

    if label and value:
        key = (
            label.get_text(strip=True)
            .replace(":", "")
            .lower()
            .replace(" ", "_")
        )
        data[key] = value.get_text(strip=True)

print("India Data Extracted :\n")
for k, v in data.items():
    print(f"{k}: {v}")

df = pd.DataFrame([data])
df.to_csv("data/india_test.csv", index=False)
print("Saved to data/india_test.csv")
# Out:
# India Data Extracted :
#
# country: 2026India Military Strength
# power_index_rank: None
# power_index_score: 0.1346
# purchasing_power_parity: 3
# foreign_exchange/gold: 5
# defense_budget: 5
# external_debt: 110
# square_land_area: 7
# coastline_coverage: 91
# shared_borders: 129
# waterways_(usable): 10
# total_population: 2
# available_manpower: 2
# fit-for-service: 2
# reaching_mil_age_annually: 1
# tot_mil._personnel_(est.): 4,958,000
# active_personnel: 2
# reserve_personnel: 8
# paramilitary: 2
# air_force_personnel*: 3
# army_personnel*: 3
# navy_personnel*: 4
# yearly_mobilization_potential: 23,652,761
# aircraft_total: 4
# fighters: 4
# attack_types: 4
# transports_(fixed-wing): 4
# trainers: 8
# special-mission: 5
# tanker_fleet: 11
# helicopters: 4
# attack_helicopters: 9
# tanks: 5
# vehicles: 2
# self-propelled_artillery: 35
# towed_artillery: 3
# mlrs_(rocket_artillery): 16
# total_assets: 4
# total_tonnage: 5
# aircraft_carriers: 3
# helicopter_carriers: 145
# destroyers: 5
# frigates: 3
# corvettes: 5
# submarines: 7
# patrol_vessels: 7
# mine_warfare: 145
# oil_production: 21
# oil_consumption: 127
# oil_deficit: -4,449,000 bbl
# oil_proven_reserves: 22
# natural_gas_production: 23
# natural_gas_consumption: 98
# natural_gas_deficit: -25,697,000,000 cu.m
# nat.gas_proven_rez: 24
# coal_production: 2
# coal_consumption: 118
# coal_deficit: -242,000,000 mt
# coal_proven_reserves: 5
# internet_coverage: 37
# labor_force: 2
# merchant_marine_fleet: 12
# ports_/_trade_terminals: 13
# airports: 22
# roadway_coverage: 2
# railway_coverage: 4
# Saved to data/india_test.csv

# %% [markdown]
# ##### Step1: Read URLs from file Step2: Loop through URLs & collect data
#
# ##### These cells repeat the same scraping process for different countries by modifying the country_id in the URL.

# %%
import os
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd

os.makedirs("data", exist_ok=True)

url = "https://www.globalfirepower.com/country-military-strength-detail.php?country_id=india"
response = requests.get(url, timeout=15)
response.raise_for_status()

# Use built-in parser if lxml not installed
soup = BeautifulSoup(response.text, "html.parser")
data = {}

title = soup.find("h1")
if title:
    data["country"] = title.get_text(strip=True)

overview_text = soup.find("span", class_="textNormal")
if overview_text:
    text = overview_text.get_text(" ", strip=True)
    rank_match = re.search(r"ranked\s#(\d+)", text)
    score_match = re.search(r"score of\s([\d.]+)", text)

    data["power_index_rank"] = rank_match.group(1) if rank_match else None
    data["power_index_score"] = score_match.group(1) if score_match else None

metric_blocks = soup.find_all("div", class_="specsGenContainers")
for block in metric_blocks:
    label = block.find("span", class_="textLarge")
    value = block.find("span", class_="textWhite")

    if label and value:
        key = (
            label.get_text(strip=True)
            .replace(":", "")
            .lower()
            .replace(" ", "_")
        )
        data[key] = value.get_text(strip=True)

print("USA Data Extracted :\n")
for k, v in data.items():
    print(f"{k}: {v}")

df = pd.DataFrame([data])
df.to_csv("data/United States_test.csv", index=False)
print("Saved to data/United States_test.csv")
# Out:
# USA Data Extracted :
#
# country: 2026India Military Strength
# power_index_rank: None
# power_index_score: 0.1346
# purchasing_power_parity: 3
# foreign_exchange/gold: 5
# defense_budget: 5
# external_debt: 110
# square_land_area: 7
# coastline_coverage: 91
# shared_borders: 129
# waterways_(usable): 10
# total_population: 2
# available_manpower: 2
# fit-for-service: 2
# reaching_mil_age_annually: 1
# tot_mil._personnel_(est.): 4,958,000
# active_personnel: 2
# reserve_personnel: 8
# paramilitary: 2
# air_force_personnel*: 3
# army_personnel*: 3
# navy_personnel*: 4
# yearly_mobilization_potential: 23,652,761
# aircraft_total: 4
# fighters: 4
# attack_types: 4
# transports_(fixed-wing): 4
# trainers: 8
# special-mission: 5
# tanker_fleet: 11
# helicopters: 4
# attack_helicopters: 9
# tanks: 5
# vehicles: 2
# self-propelled_artillery: 35
# towed_artillery: 3
# mlrs_(rocket_artillery): 16
# total_assets: 4
# total_tonnage: 5
# aircraft_carriers: 3
# helicopter_carriers: 145
# destroyers: 5
# frigates: 3
# corvettes: 5
# submarines: 7
# patrol_vessels: 7
# mine_warfare: 145
# oil_production: 21
# oil_consumption: 127
# oil_deficit: -4,449,000 bbl
# oil_proven_reserves: 22
# natural_gas_production: 23
# natural_gas_consumption: 98
# natural_gas_deficit: -25,697,000,000 cu.m
# nat.gas_proven_rez: 24
# coal_production: 2
# coal_consumption: 118
# coal_deficit: -242,000,000 mt
# coal_proven_reserves: 5
# internet_coverage: 37
# labor_force: 2
# merchant_marine_fleet: 12
# ports_/_trade_terminals: 13
# airports: 22
# roadway_coverage: 2
# railway_coverage: 4
# Saved to data/United States_test.csv

# %%
import os
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd

os.makedirs("data", exist_ok=True)

url = "https://www.globalfirepower.com/country-military-strength-detail.php?country_id=india"
response = requests.get(url, timeout=15)
response.raise_for_status()

# Use built-in parser if lxml not installed
soup = BeautifulSoup(response.text, "html.parser")
data = {}

title = soup.find("h1")
if title:
    data["country"] = title.get_text(strip=True)

overview_text = soup.find("span", class_="textNormal")
if overview_text:
    text = overview_text.get_text(" ", strip=True)
    rank_match = re.search(r"ranked\s#(\d+)", text)
    score_match = re.search(r"score of\s([\d.]+)", text)

    data["power_index_rank"] = rank_match.group(1) if rank_match else None
    data["power_index_score"] = score_match.group(1) if score_match else None

metric_blocks = soup.find_all("div", class_="specsGenContainers")
for block in metric_blocks:
    label = block.find("span", class_="textLarge")
    value = block.find("span", class_="textWhite")

    if label and value:
        key = (
            label.get_text(strip=True)
            .replace(":", "")
            .lower()
            .replace(" ", "_")
        )
        data[key] = value.get_text(strip=True)

print("china Data Extracted :\n")
for k, v in data.items():
    print(f"{k}: {v}")

df = pd.DataFrame([data])
df.to_csv("data/china_test.csv", index=False)
print("Saved to data/china_test.csv")
# Out:
# china Data Extracted :
#
# country: 2026India Military Strength
# power_index_rank: None
# power_index_score: 0.1346
# purchasing_power_parity: 3
# foreign_exchange/gold: 5
# defense_budget: 5
# external_debt: 110
# square_land_area: 7
# coastline_coverage: 91
# shared_borders: 129
# waterways_(usable): 10
# total_population: 2
# available_manpower: 2
# fit-for-service: 2
# reaching_mil_age_annually: 1
# tot_mil._personnel_(est.): 4,958,000
# active_personnel: 2
# reserve_personnel: 8
# paramilitary: 2
# air_force_personnel*: 3
# army_personnel*: 3
# navy_personnel*: 4
# yearly_mobilization_potential: 23,652,761
# aircraft_total: 4
# fighters: 4
# attack_types: 4
# transports_(fixed-wing): 4
# trainers: 8
# special-mission: 5
# tanker_fleet: 11
# helicopters: 4
# attack_helicopters: 9
# tanks: 5
# vehicles: 2
# self-propelled_artillery: 35
# towed_artillery: 3
# mlrs_(rocket_artillery): 16
# total_assets: 4
# total_tonnage: 5
# aircraft_carriers: 3
# helicopter_carriers: 145
# destroyers: 5
# frigates: 3
# corvettes: 5
# submarines: 7
# patrol_vessels: 7
# mine_warfare: 145
# oil_production: 21
# oil_consumption: 127
# oil_deficit: -4,449,000 bbl
# oil_proven_reserves: 22
# natural_gas_production: 23
# natural_gas_consumption: 98
# natural_gas_deficit: -25,697,000,000 cu.m
# nat.gas_proven_rez: 24
# coal_production: 2
# coal_consumption: 118
# coal_deficit: -242,000,000 mt
# coal_proven_reserves: 5
# internet_coverage: 37
# labor_force: 2
# merchant_marine_fleet: 12
# ports_/_trade_terminals: 13
# airports: 22
# roadway_coverage: 2
# railway_coverage: 4
# Saved to data/china_test.csv

# %%
import os
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd

os.makedirs("data", exist_ok=True)

url = "https://www.globalfirepower.com/country-military-strength-detail.php?country_id=india"
response = requests.get(url, timeout=15)
response.raise_for_status()

# Use built-in parser if lxml not installed
soup = BeautifulSoup(response.text, "html.parser")
data = {}

title = soup.find("h1")
if title:
    data["country"] = title.get_text(strip=True)

overview_text = soup.find("span", class_="textNormal")
if overview_text:
    text = overview_text.get_text(" ", strip=True)
    rank_match = re.search(r"ranked\s#(\d+)", text)
    score_match = re.search(r"score of\s([\d.]+)", text)

    data["power_index_rank"] = rank_match.group(1) if rank_match else None
    data["power_index_score"] = score_match.group(1) if score_match else None

metric_blocks = soup.find_all("div", class_="specsGenContainers")
for block in metric_blocks:
    label = block.find("span", class_="textLarge")
    value = block.find("span", class_="textWhite")

    if label and value:
        key = (
            label.get_text(strip=True)
            .replace(":", "")
            .lower()
            .replace(" ", "_")
        )
        data[key] = value.get_text(strip=True)

print("Indonesia Data Extracted :\n")
for k, v in data.items():
    print(f"{k}: {v}")

df = pd.DataFrame([data])
df.to_csv("data/indonesia_test.csv", index=False)
print("Saved to data/indonesia_test.csv")
# Out:
# Indonesia Data Extracted :
#
# country: 2026India Military Strength
# power_index_rank: None
# power_index_score: 0.1346
# purchasing_power_parity: 3
# foreign_exchange/gold: 5
# defense_budget: 5
# external_debt: 110
# square_land_area: 7
# coastline_coverage: 91
# shared_borders: 129
# waterways_(usable): 10
# total_population: 2
# available_manpower: 2
# fit-for-service: 2
# reaching_mil_age_annually: 1
# tot_mil._personnel_(est.): 4,958,000
# active_personnel: 2
# reserve_personnel: 8
# paramilitary: 2
# air_force_personnel*: 3
# army_personnel*: 3
# navy_personnel*: 4
# yearly_mobilization_potential: 23,652,761
# aircraft_total: 4
# fighters: 4
# attack_types: 4
# transports_(fixed-wing): 4
# trainers: 8
# special-mission: 5
# tanker_fleet: 11
# helicopters: 4
# attack_helicopters: 9
# tanks: 5
# vehicles: 2
# self-propelled_artillery: 35
# towed_artillery: 3
# mlrs_(rocket_artillery): 16
# total_assets: 4
# total_tonnage: 5
# aircraft_carriers: 3
# helicopter_carriers: 145
# destroyers: 5
# frigates: 3
# corvettes: 5
# submarines: 7
# patrol_vessels: 7
# mine_warfare: 145
# oil_production: 21
# oil_consumption: 127
# oil_deficit: -4,449,000 bbl
# oil_proven_reserves: 22
# natural_gas_production: 23
# natural_gas_consumption: 98
# natural_gas_deficit: -25,697,000,000 cu.m
# nat.gas_proven_rez: 24
# coal_production: 2
# coal_consumption: 118
# coal_deficit: -242,000,000 mt
# coal_proven_reserves: 5
# internet_coverage: 37
# labor_force: 2
# merchant_marine_fleet: 12
# ports_/_trade_terminals: 13
# airports: 22
# roadway_coverage: 2
# railway_coverage: 4
# Saved to data/indonesia_test.csv

# %%
import os
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd

os.makedirs("data", exist_ok=True)

url = "https://www.globalfirepower.com/country-military-strength-detail.php?country_id=india"
response = requests.get(url, timeout=15)
response.raise_for_status()

# Use built-in parser if lxml not installed
soup = BeautifulSoup(response.text, "html.parser")
data = {}

title = soup.find("h1")
if title:
    data["country"] = title.get_text(strip=True)

overview_text = soup.find("span", class_="textNormal")
if overview_text:
    text = overview_text.get_text(" ", strip=True)
    rank_match = re.search(r"ranked\s#(\d+)", text)
    score_match = re.search(r"score of\s([\d.]+)", text)

    data["power_index_rank"] = rank_match.group(1) if rank_match else None
    data["power_index_score"] = score_match.group(1) if score_match else None

metric_blocks = soup.find_all("div", class_="specsGenContainers")
for block in metric_blocks:
    label = block.find("span", class_="textLarge")
    value = block.find("span", class_="textWhite")

    if label and value:
        key = (
            label.get_text(strip=True)
            .replace(":", "")
            .lower()
            .replace(" ", "_")
        )
        data[key] = value.get_text(strip=True)

print("Pakistan Data Extracted :\n")
for k, v in data.items():
    print(f"{k}: {v}")

df = pd.DataFrame([data])
df.to_csv("data/Pakistan_test.csv", index=False)
print("Saved to data/Pakistan_test.csv")
# Out:
# Pakistan Data Extracted :
#
# country: 2026India Military Strength
# power_index_rank: None
# power_index_score: 0.1346
# purchasing_power_parity: 3
# foreign_exchange/gold: 5
# defense_budget: 5
# external_debt: 110
# square_land_area: 7
# coastline_coverage: 91
# shared_borders: 129
# waterways_(usable): 10
# total_population: 2
# available_manpower: 2
# fit-for-service: 2
# reaching_mil_age_annually: 1
# tot_mil._personnel_(est.): 4,958,000
# active_personnel: 2
# reserve_personnel: 8
# paramilitary: 2
# air_force_personnel*: 3
# army_personnel*: 3
# navy_personnel*: 4
# yearly_mobilization_potential: 23,652,761
# aircraft_total: 4
# fighters: 4
# attack_types: 4
# transports_(fixed-wing): 4
# trainers: 8
# special-mission: 5
# tanker_fleet: 11
# helicopters: 4
# attack_helicopters: 9
# tanks: 5
# vehicles: 2
# self-propelled_artillery: 35
# towed_artillery: 3
# mlrs_(rocket_artillery): 16
# total_assets: 4
# total_tonnage: 5
# aircraft_carriers: 3
# helicopter_carriers: 145
# destroyers: 5
# frigates: 3
# corvettes: 5
# submarines: 7
# patrol_vessels: 7
# mine_warfare: 145
# oil_production: 21
# oil_consumption: 127
# oil_deficit: -4,449,000 bbl
# oil_proven_reserves: 22
# natural_gas_production: 23
# natural_gas_consumption: 98
# natural_gas_deficit: -25,697,000,000 cu.m
# nat.gas_proven_rez: 24
# coal_production: 2
# coal_consumption: 118
# coal_deficit: -242,000,000 mt
# coal_proven_reserves: 5
# internet_coverage: 37
# labor_force: 2
# merchant_marine_fleet: 12
# ports_/_trade_terminals: 13
# airports: 22
# roadway_coverage: 2
# railway_coverage: 4
# Saved to data/Pakistan_test.csv

# %%
import os
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd

os.makedirs("data", exist_ok=True)

url = "https://www.globalfirepower.com/country-military-strength-detail.php?country_id=india"
response = requests.get(url, timeout=15)
response.raise_for_status()

# Use built-in parser if lxml not installed
soup = BeautifulSoup(response.text, "html.parser")
data = {}

title = soup.find("h1")
if title:
    data["country"] = title.get_text(strip=True)

overview_text = soup.find("span", class_="textNormal")
if overview_text:
    text = overview_text.get_text(" ", strip=True)
    rank_match = re.search(r"ranked\s#(\d+)", text)
    score_match = re.search(r"score of\s([\d.]+)", text)

    data["power_index_rank"] = rank_match.group(1) if rank_match else None
    data["power_index_score"] = score_match.group(1) if score_match else None

metric_blocks = soup.find_all("div", class_="specsGenContainers")
for block in metric_blocks:
    label = block.find("span", class_="textLarge")
    value = block.find("span", class_="textWhite")

    if label and value:
        key = (
            label.get_text(strip=True)
            .replace(":", "")
            .lower()
            .replace(" ", "_")
        )
        data[key] = value.get_text(strip=True)

print("Australia Data Extracted :\n")
for k, v in data.items():
    print(f"{k}: {v}")

df = pd.DataFrame([data])
df.to_csv("data/Australia_test.csv", index=False)
print("Saved to data/Australia_test.csv")
# Out:
# Australia Data Extracted :
#
# country: 2026India Military Strength
# power_index_rank: None
# power_index_score: 0.1346
# purchasing_power_parity: 3
# foreign_exchange/gold: 5
# defense_budget: 5
# external_debt: 110
# square_land_area: 7
# coastline_coverage: 91
# shared_borders: 129
# waterways_(usable): 10
# total_population: 2
# available_manpower: 2
# fit-for-service: 2
# reaching_mil_age_annually: 1
# tot_mil._personnel_(est.): 4,958,000
# active_personnel: 2
# reserve_personnel: 8
# paramilitary: 2
# air_force_personnel*: 3
# army_personnel*: 3
# navy_personnel*: 4
# yearly_mobilization_potential: 23,652,761
# aircraft_total: 4
# fighters: 4
# attack_types: 4
# transports_(fixed-wing): 4
# trainers: 8
# special-mission: 5
# tanker_fleet: 11
# helicopters: 4
# attack_helicopters: 9
# tanks: 5
# vehicles: 2
# self-propelled_artillery: 35
# towed_artillery: 3
# mlrs_(rocket_artillery): 16
# total_assets: 4
# total_tonnage: 5
# aircraft_carriers: 3
# helicopter_carriers: 145
# destroyers: 5
# frigates: 3
# corvettes: 5
# submarines: 7
# patrol_vessels: 7
# mine_warfare: 145
# oil_production: 21
# oil_consumption: 127
# oil_deficit: -4,449,000 bbl
# oil_proven_reserves: 22
# natural_gas_production: 23
# natural_gas_consumption: 98
# natural_gas_deficit: -25,697,000,000 cu.m
# nat.gas_proven_rez: 24
# coal_production: 2
# coal_consumption: 118
# coal_deficit: -242,000,000 mt
# coal_proven_reserves: 5
# internet_coverage: 37
# labor_force: 2
# merchant_marine_fleet: 12
# ports_/_trade_terminals: 13
# airports: 22
# roadway_coverage: 2
# railway_coverage: 4
# Saved to data/Australia_test.csv

# %%
import os
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd

os.makedirs("data", exist_ok=True)

url = "https://www.globalfirepower.com/country-military-strength-detail.php?country_id=india"
response = requests.get(url, timeout=15)
response.raise_for_status()

# Use built-in parser if lxml not installed
soup = BeautifulSoup(response.text, "html.parser")
data = {}

title = soup.find("h1")
if title:
    data["country"] = title.get_text(strip=True)

overview_text = soup.find("span", class_="textNormal")
if overview_text:
    text = overview_text.get_text(" ", strip=True)
    rank_match = re.search(r"ranked\s#(\d+)", text)
    score_match = re.search(r"score of\s([\d.]+)", text)

    data["power_index_rank"] = rank_match.group(1) if rank_match else None
    data["power_index_score"] = score_match.group(1) if score_match else None

metric_blocks = soup.find_all("div", class_="specsGenContainers")
for block in metric_blocks:
    label = block.find("span", class_="textLarge")
    value = block.find("span", class_="textWhite")

    if label and value:
        key = (
            label.get_text(strip=True)
            .replace(":", "")
            .lower()
            .replace(" ", "_")
        )
        data[key] = value.get_text(strip=True)

print("Afganistan Data Extracted :\n")
for k, v in data.items():
    print(f"{k}: {v}")

df = pd.DataFrame([data])
df.to_csv("data/Afganistan_test.csv", index=False)
print("Saved to data/Afganistan_test.csv")
# Out:
# Afganistan Data Extracted :
#
# country: 2026India Military Strength
# power_index_rank: None
# power_index_score: 0.1346
# purchasing_power_parity: 3
# foreign_exchange/gold: 5
# defense_budget: 5
# external_debt: 110
# square_land_area: 7
# coastline_coverage: 91
# shared_borders: 129
# waterways_(usable): 10
# total_population: 2
# available_manpower: 2
# fit-for-service: 2
# reaching_mil_age_annually: 1
# tot_mil._personnel_(est.): 4,958,000
# active_personnel: 2
# reserve_personnel: 8
# paramilitary: 2
# air_force_personnel*: 3
# army_personnel*: 3
# navy_personnel*: 4
# yearly_mobilization_potential: 23,652,761
# aircraft_total: 4
# fighters: 4
# attack_types: 4
# transports_(fixed-wing): 4
# trainers: 8
# special-mission: 5
# tanker_fleet: 11
# helicopters: 4
# attack_helicopters: 9
# tanks: 5
# vehicles: 2
# self-propelled_artillery: 35
# towed_artillery: 3
# mlrs_(rocket_artillery): 16
# total_assets: 4
# total_tonnage: 5
# aircraft_carriers: 3
# helicopter_carriers: 145
# destroyers: 5
# frigates: 3
# corvettes: 5
# submarines: 7
# patrol_vessels: 7
# mine_warfare: 145
# oil_production: 21
# oil_consumption: 127
# oil_deficit: -4,449,000 bbl
# oil_proven_reserves: 22
# natural_gas_production: 23
# natural_gas_consumption: 98
# natural_gas_deficit: -25,697,000,000 cu.m
# nat.gas_proven_rez: 24
# coal_production: 2
# coal_consumption: 118
# coal_deficit: -242,000,000 mt
# coal_proven_reserves: 5
# internet_coverage: 37
# labor_force: 2
# merchant_marine_fleet: 12
# ports_/_trade_terminals: 13
# airports: 22
# roadway_coverage: 2
# railway_coverage: 4
# Saved to data/Afganistan_test.csv

# %% [markdown]
# Step1: Validate scraped data Step2: Export raw dataset Militar_raw_data.csv
#
# This step imports the required libraries. Pandas is used for data manipulation and file handling, while the OS module is used to interact with the file system.

# %% [markdown]
# import pandas as pd
# import os

# %% [markdown]
# ##### This step reads all country CSV files from the data folder and combines them into a single dataset.

# %%
folder_path="data"
all_files=[f for f in os.listdir(folder_path) if f.endswith(".csv")]
df_list=[]
for file in all_files:
    file_path=os.path.join(folder_path,file)
    df=pd.read_csv(file_path)
    df_list.append(df)
combined_df=pd.concat(df_list,ignore_index=True)
combined_df
# Out:
#                               country  power_index_rank  power_index_score  \
# 0         2026India Military Strength               NaN             0.1346
# 1         2026India Military Strength               NaN             0.1346
# 2         2026India Military Strength               NaN             0.1346
# 3         2026India Military Strength               NaN             0.1346
# 4         2026India Military Strength               NaN             0.1346
# 5         2026India Military Strength               4.0             0.1346
# 6   2026Afghanistan Military Strength             121.0             2.7342
# 7         2026China Military Strength               3.0             0.0919
# 8        2026Russia Military Strength               2.0             0.0791
# 9        2026France Military Strength               6.0             0.1798
# 10        2026India Military Strength               NaN             0.1346
# 11        2026India Military Strength               NaN             0.1346
#
#     purchasing_power_parity  foreign_exchange/gold  defense_budget  \
# 0                         3                      5               5
# 1                         3                      5               5
# 2                         3                      5               5
# 3                         3                      5               5
# 4                         3                      5               5
# 5                         3                      5               5
# 6                       101                     84             136
# 7                         1                      1               2
# 8                         4                      6               3
# 9                         9                     15               7
# 10                        3                      5               5
# 11                        3                      5               5
#
#     external_debt  square_land_area  coastline_coverage  shared_borders  ...  \
# 0             110                 7                  91             129  ...
# 1             110                 7                  91             129  ...
# 2             110                 7                  91             129  ...
# 3             110                 7                  91             129  ...
# 4             110                 7                  91             129  ...
# 5             110                 7                  91             129  ...
# 6               8                41                 999             109  ...
# 7             121                 4                  98             132  ...
# 8             112                 1                 105             131  ...
# 9             143                43                  85              81  ...
# 10            110                 7                  91             129  ...
# 11            110                 7                  91             129  ...
#
#     coal_consumption     coal_deficit  coal_proven_reserves  \
# 0                118  -242,000,000 mt                     5
# 1                118  -242,000,000 mt                     5
# 2                118  -242,000,000 mt                     5
# 3                118  -242,000,000 mt                     5
# 4                118  -242,000,000 mt                     5
# 5                118  -242,000,000 mt                     5
# 6                 38      +264,000 mt                    71
# 7                119  -386,000,000 mt                     3
# 8                116  +240,367,000 mt                     2
# 9                 88   -10,413,000 mt                    63
# 10               118  -242,000,000 mt                     5
# 11               118  -242,000,000 mt                     5
#
#     internet_coverage  labor_force merchant_marine_fleet  \
# 0                  37            2                    12
# 1                  37            2                    12
# 2                  37            2                    12
# 3                  37            2                    12
# 4                  37            2                    12
# 5                  37            2                    12
# 6                  57           59                   145
# 7                  22            1                     2
# 8                   9            9                     8
# 9                  14           22                    34
# 10                 37            2                    12
# 11                 37            2                    12
#
#     ports_/_trade_terminals  airports  roadway_coverage  railway_coverage
# 0                        13        22                 2                 4
# 1                        13        22                 2                 4
# 2                        13        22                 2                 4
# 3                        13        22                 2                 4
# 4                        13        22                 2                 4
# 5                        13        22                 2                 4
# 6                       145        61                94               145
# 7                        11        15                 3                 2
# 8                        10         8                 5                 3
# 9                        11         6                 7                10
# 10                       13        22                 2                 4
# 11                       13        22                 2                 4
#
# [12 rows x 66 columns]

# %% [markdown]
# ##### All individual country datasets were successfully merged into one combined dataset.
# ##### This step exports the combined dataset into a single CSV file for further cleaning and analysis.

# %%
combined_df.to_csv("Military_raw_data.csv",index=False)
print("Combined raw dataset saved as Military_raw_data.csv")
# Out:
# Combined raw dataset saved as Military_raw_data.csv
