# %% [markdown]
# # Scrape data from one Country

# %%
# importing all the necessary libraries
import requests
from bs4 import BeautifulSoup

url="https://www.globalfirepower.com/country-military-strength-detail.php?country_id=russia"

page = requests.get(url)

soup = BeautifulSoup(page.text, "html")
soup
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
# <head>
# <meta charset="utf-8"/>
# <title>2026 Russia Military Strength</title>
# <link href="https://www.globalfirepower.com/country-military-strength-detail.php?country_id=russia" rel="canonical"/>
# <link href="https://www.globalfirepower.com/imgs/design/logo.png" rel="image_src"/>
# <style type="text/css">@font-face {font-family:IBM Plex Sans;font-style:normal;font-weight:100;src:url(/cf-fonts/s/ibm-plex-sans/5.0.18/cyrillic/100/normal.woff2);unicode-range:U+0301,U+0400-045F,U+0490-0491,U+04B0-04B1,U+2116;font-display:swap;}@font-face {font-family:IBM Plex Sans;font-style:normal;font-weight:100;src:url(/cf-fonts/s/ibm-plex-sans/5.0.18/greek/100/normal.woff2);unicode-range:U+0370-03FF;font-display:swap;}@font-face {font-family:IBM Plex Sans;font-style:normal;font-weight:100;src:url(/cf-fonts/s/ibm-plex-sans/5.0.18/cyrillic-ext/100/normal.woff2);unicode-range:U+0460-052F,U+1C80-1C88,U+20B4,U+2DE0-2DFF,U+A640-A69F,U+FE2E-FE2F;font-display:swap;}@font-face {font-family:IBM Plex Sans;font-style:normal;font-weight:100;src:url(/cf-fonts/s/ibm-plex-sans/5.0.18/latin-ext/100/normal.woff2);unicode-range:U+0100-02AF,U+0304,U+0308,U+0329,U+1E00-1E9F,U+1EF2-1EFF,U+2020,U+20A0-20AB,U+20AD-20CF,U+2113,U+2C60-2C7F,U+A720-A7FF;font-display:swap;}@font-face {font-family:IBM Plex Sans;font-style:normal;font-weight:100;src:url(/cf-fonts/s/ibm-plex-sans/5.0.18/latin/100/normal.woff2);unicode-range:U+0000-00FF,U+0131,U+0152-0153,U+02BB-02BC,U+02C6,U+02DA,U+02DC,U+0304,U+0308,U+0329,U+2000-206F,U+2074,U+20AC,U+2122,U+2191,U+2193,U+2212,U+2215,U+FEFF,U+FFFD;font-display:swap;}@font-face {font-family:IBM Plex Sans;font-style:normal;font-weight:100;src:url(/cf-fonts/s/ibm-plex-sans/5.0.18/vietnamese/100/normal.woff2);unicode-range:U+0102-0103,U+0110-0111,U+0128-0129,U+0168-0169,U+01A0-01A1,U+01AF-01B0,U+0300-0301,U+0303-0304,U+0308-0309,U+0323,U+0329,U+1EA0-1EF9,U+20AB;font-display:swap;}@font-face {font-family:IBM Plex Sans;font-style:normal;font-weight:200;src:url(/cf-fonts/s/ibm-plex-sans/5.0.18/cyrillic/200/normal.woff2);unicode-range:U+0301,U+0400-045F,U+0490-0491,U+04B0-04B1,U+2116;font-display:swap;}@font-face {font-family:IBM Plex Sans;font-style:normal;font-weight:200;src:url(/cf-fonts/s/ibm-plex-sans/5.0.18/greek/200/normal.woff2);unicode-range:U+0370-03FF;font-display:swap;}@font-face {font-family:IBM Plex Sans;font-style:normal;font-weight:200;src:url(/cf-fonts/s/ibm-plex-sans/5.0.18/latin/200/normal.woff2);unicode-range:U+0000-00FF,U+0131,U+0152-0153,U+02BB-02BC,U+02C6,U+02DA,U+02DC,U+0304,U+0308,U+0329,U+2000-206F,U+2074,U+20AC,U+2122,U+2191,U+2193,U+2212,U+2215,U+FEFF,U+FFFD;font-display:swap;}@font-face {font-family:IBM Plex Sans;font-style:normal;font-weight:200;src:url(/cf-fonts/s/ibm-plex-sans/5.0.18/vietnamese/200/normal.woff2);unicode-range:U+0102-0103,U+0110-0111,U+0128-0129,U+0168-0169,U+01A0-01A1,U+01AF-01B0,U+0300-0301,U+0303-0304,U+0308-0309,U+0323,U+0329,U+1EA0-1EF9,U+20AB;font-display:swap;}@font-face {font-family:IBM Plex Sans;font-style:normal;font-weight:200;src:url(/cf-fonts/s/ibm-plex-sans/5.0.18/latin-ext/200/normal.woff2);unicode-range:U+0100-02AF,U+0304,U+0308,U+0329,U+1E00-1E9F,U+1EF2-1EFF,U+2020,U+20A0-20AB,U+20AD-20CF,U+2113,U+2C60-2C7F,U+A720-A7FF;font-display:swap;}@font-face {font-family:IBM Plex Sans;font-style:normal;font-weight:200;src:url(/cf-fonts/s/ibm-plex-sans/5.0.18/cyrillic-ext/200/normal.woff2);unicode-range:U+0460-052F,U+1C80-1C88,U+20B4,U+2DE0-2DFF,U+A640-A69F,U+FE2E-FE2F;font-display:swap;}@font-face {font-family:IBM Plex Sans;font-style:normal;font-weight:300;src:url(/cf-fonts/s/ibm-plex-sans/5.0.18/latin-ext/300/normal.woff2);unicode-range:U+0100-02AF,U+0304,U+0308,U+0329,U+1E00-1E9F,U+1EF2-1EFF,U+2020,U+20A0-20AB,U+20AD-20CF,U+2113,U+2C60-2C7F,U+A720-A7FF;font-display:swap;}@font-face {font-family:IBM Plex Sans;font-style:normal;font-weight:300;src:url(/cf-fonts/s/ibm-plex-sans/5.0.18/cyrillic/300/normal.woff2);unicode-range:U+0301,U+0400-045F,U+0490-0491,U+04B0-04B1,U+2116;font-display:swap;}@font-face {font-family:IBM Plex Sans;font-style:normal;font-weight:300;src:url(/cf-fonts/s/ibm-plex-sans/5.0.18/cyrillic-ext/300/normal.woff2);unicode-range:U+0460-052F,U+1C80-1C88,U+20B4,U+2DE0-2DFF,U+A640-A69F,U+FE2E-FE2F;font-display:swap;}@font-face {font-family:IBM Plex Sans;fon ...
# <meta content="initial-scale=1, maximum-scale=2" name="viewport"/>
# <meta content="Detailing the current military strength of Russia including air force, army, navy, financials and manpower." name="description"/>
# <meta content="russia, 2026, country, nation, national, military, strength, detail, numbers, by-the-numbers, data, numeric, comparison, regional, local, power, firepower, land, sea, air, manpower, personnel, army, navy, air force, oil, natural gas, coal, reserves, proven, estimated, resources, global, world, current, readiness rates, charts, algorithm, formula, power index rating, warfare, modern, current, warpower, analytics, breakdown, overview, pocket guide, geography, financials, aggregator, naval forces, units, end-use products, natual resources, airpower, land forces, tanks, vehicles, artilley, rocket projectors, mobile, capital cities, ranked, ranking, invasion, at-a-glance, basics, logistics, infrastructure" name="keywords"/>
# <meta content="www.GlobalFirepower.com" name="copyright"/>
# <meta content="nopin" name="pinterest"/>
# <meta content="2026 Russia Military Strength" property="og:title"/>
# <meta content="article" property="og:type"/>
# <meta content="https://www.globalfirepower.com/country-military-strength-detail.php?country_id=russia" property="og:url"/>
# <meta content="Detailing the current military strength of Russia including air force, army, navy, financials and manpower." property="og:description"/>
# <style>/* Global */*{box-sizing:border-box; padding:0; margin:0;}body, html{width:100vw; font-family:"IBM Plex Sans", sans-serif; overflow-x:hidden; box-sizing:border-box; scroll-behavior:smooth;}/* Basic link colors-effects */a:link{text-decoration:underline;color:#036;}a:visited{text-decoration:underline;color:#333;}a:hover{text-decoration:none;color:#336;}a:active{text-decoration:underline;color:#FC0;}/* Footer Links */a.footerLink:link{color:#fff;text-decoration:none;}a.footerLink:visited{color:#fff;text-decoration:none;}a.footerLink:hover{color:#FC0;text-decoration:none;}a.footerLink:active{color:#FC0;text-decoration:none;}h1{font-size:calc(42px + 6 * ((100vw - 320px)/680)); font-weight:400; display:inline; line-height:120%;}h2{font-size:calc(32px + 6 * ((100vw - 320px)/680)); font-weight:400; display:inline; line-height:120%;}h3{font-size:calc(20px + 6 * ((100vw - 320px)/680)); line-height:120%; display:inline;}h4{font-size:calc(16px + 6 * ((100vw - 320px)/680)); line-height:120%; display:inline;}/* Text sizes */.textSmall1{font-size:0.90em; line-height:140%; user-select:none;}.textSmall2{font-size:0.75em; line-height:140%; user-select:none;}.textSmall3{font-size:0.65em; line-height:140%; user-select:none;}.textNormal{font-size:1.0em; line-height:165%; user-select:none;}.textBold{font-weight:bold;}.textItalics{font-style:italic;}.textLarge{font-size:20px; line-height:165%;}.textLarger{font-size:24px; line-height:150%;}.textLargest{font-size:32px; line-height:120%;}.textJumbo{font-size:48px; line-height:120%;}/* Text colors */ .textWhite{color:#fff;}.textDkGray{color:#333;}.textLtGray{color:#666;}.textLtrGray{color:#999;}.textLtstGray{color:#ccc;}.textYellow{color:#fc0;}.textDkBlue{color:#036;}.textYellowOrange{color:#ffab31;}.textBrtBlue{color:#0CF;}.textRed{color:#C00;}.textGreen{color:#090;}.textBrtGreen{color:#0C0;}/* Universal wide container */.contentStripOuter{width:100%; display:inline-block; position:relative; text-align:center; box-sizing:border-box;}.contentStripInner{width:100%; max-width:1600px; display:inline-block; position:relative; box-sizing:border-box;}/* Underscore blocks */.contentBlockUnderscore{width:200px; height:5px; display:inline-block; position:relative; background-color:#660; margin:15px 0px 15px 0px;}/* Accent colors */.accentColor1{background-color:#036;}.accentColor2{background-color:#FC0;}.accentColor3{background-color:#900;}.accentColor4{background-color:#F60;}/* Left and Right Content Blocks */.leftColBlock{width:50%; max-width:800px; display:inline-block; position:relative; float:left; padding:3%; box-sizing:border-box;}.rightColBlock{width:50%; max-width:800px; display:inline-block; position:relative; float:right; padding:3%; box-sizing:border-box;}/* Img actions-effects */.picTrans:hover{filter:brightness(110%);}.picTrans2:hover{background-color:#dfdfdf;}.picTrans3:hover{border:1px solid #FC0; cursor:pointer;}.zoom{transition:transform .2s;}.zoom:hover{transform:scale(1.01); z-index:777;}.textShadow{text-shadow:0px 2px 0px #000;}.boxShadow{box-shadow:0px 4px 8px 0px rgba(0,0,0,0.2), 0px 6px 20px 0px rgba(0,0,0,0.19);}} /* Main header menu */ .mainMenu{width:100%; display:inline-block; position:relative;}.mmLogo{width:100%; max-width:200px; display:inline-block; position:relative; padding:22px 0 15px 0; text-align:center;}.smallGraphIcon{width:auto; height:auto; display:inline-block; position:absolute; top:0; right:0; margin:10px 10px 0px 0px;} @media only screen and (max-width:800px){.leftColBlock{width:100%; max-width:none; margin:0; padding:5%; float:none;}.rightColBlock{width:100%; max-width:none; margin:0; padding:5%; float:none; text-align:center;}}
# </style><!-- Global site tag (gtag.js) - Google Analytics --><script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-864198-8"></script><script>window.dataLayer = window.dataLayer || []; function gtag(){dataLayer.push(arguments);} gtag('js', new Date()); gtag('config', 'UA-864198-8');</script><!--Google Analytics--><script>if (window.top !== window.self) window.top.location.replace(window.self.location.href);</script><!--AUTOADS--><script async="" crossorigin="anonymous" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js?client=ca-pub-5604186322601931"></script><!--AUTOADS--><!-- Google tag (gtag.js) --><script async="" src="https://www.googletagmanager.com/gtag/js?id=G-TXJ5P6EMGK"></script><script>window.dataLayer = window.dataLayer || []; function gtag(){dataLayer.push(arguments);} gtag('js', new Date()); gtag('config', 'G-TXJ5P6EMGK');</script><!--MCClarity--><script type="text/javascript">(function(c,l,a,r,i,t,y){c[a]=c[a]||function(){(c[a].q=c[a].q||[]).push(arguments)}; t=l.createElement(r);t.async=1;t.src="https://www.clarity.ms/tag/"+i; y=l.getElementsByTagName(r)[0];y.parentNode.insertBefore(t,y);})(window, document, "clarity", "script", "flewv0tc1c");</script><!--MCClarity--></head>
# <body>
# <!--HEADERLOGOMENUAREA-->
# <div class="mainMenu" style="text-align:center; background-color:#fff; border-bottom:1px solid #ccc; padding-bottom:15px;">
# <a href="https://www.globalfirepower.com/" title="Global Firepower - World Military Strength">
# <div class="picTrans mmLogo">
# <img alt="GlobalFirepower.com logo" loading="lazy" src="/imgs/design/logo-2025.png" style="width:150px; height:51px; display:inline-block;"/>
# </div></a>
# <br/>
# <span class="textSmall1 textLtGray">The leading annual global defense review since 2005</span>
# <br/><br/>
# <div class="hamburgerFormatting" onclick="openNav()">
# <img alt="Main menu hamburger icon" src="/imgs/design/hamburger.png" style="width:20px; height:20px;"/>
# <br/>
# <span class="textSmall1 textDkGray">MENU</span>
# </div>
# <div class="miniNav">
# <a href="/countries-listing.php" title="2025 military defense review">
# <div class="headerOptions">
# <span class="textLtGray textSmall2 textBold">2026 RANKINGS</span>
# </div></a>
# <a href="/countries.php" title="Complete countries list, A to Z">
# <div class="headerOptions">
# <span class="textLtGray textSmall2 textBold">NATIONS INDEX</span>
# </div></a>
# <a href="/countries-comparison.php" title="Compare the military power of any two countries">
# <div class="headerOptions">
# <span class="textLtGray textSmall2 textBold">COMPARISONS</span>
# </div></a>
# <a href="/coalitions.php" title="Build your own coalitions to see what World War III might look like">
# <div class="headerOptions">
# <span class="textLtGray textSmall2 textBold">COALITIONS BUILDER</span>
# </div></a>
# <a href="/global-ranks-previous.php" title="Past rankings of top military powers since the year 2005">
# <div class="headerOptions">
# <span class="textLtGray textSmall2 textBold">PAST RANKINGS</span>
# </div></a>
# </div>
# </div>
# <!--HEADERLOGOMENUAREA-->
# <!--MAINMENU-->
# <style>
# .hamburgerFormatting{width:100%; max-width:100px; display:inline-block; position:absolute; top:0; right:20px; padding:25px 20px; margin:0; text-align:center; border-left:1px solid #fff; box-sizing:border-box; cursor:pointer;}
# .headerOptions{width:auto; display:inline-block; position:relative; padding:3px 25px;}
# .overlay{height:100%; width:0; display:inline-block; position:fixed; z-index:999; top:0; right:0; background-color:#16d0c5; overflow-x:hidden; transition:0.5s; border:1px solid #999;}
# .overlay-content{position:relative; top:10%; width:100%; text-align:left; margin-top:7px; padding:0 20px;}
# .overlay a{padding:8px; text-decoration:none; font-size:16px; line-height:100%; color:#00163b; display:block; transition:0.3s; border:1px solid #16d0c5;}
# .overlay a:hover, .overlay a:focus{color:#fff; border:1px solid #fff;}
# .overlay .closebtn{position:absolute; top:15px; right:15px; font-size:30px; color:#00163b; border:1px solid #00163b; padding:0 15px;}
# .overlay-content a:hover{background-color:#333;}
#
# .menuLineBreak{width:100%; height:1px; display:inline-block; position:relative; background-color:#00163b; margin:15px 0; opacity:0.15;}
# .miniNav{width:100%; display:inline-block; position:relative; text-align:center;}
#
# @media screen and (max-width:800px) {
# 	.miniNav{display:none;}
# }
#
# @media screen and (max-width:640px) {
# 	.hamburgerFormatting{max-width:60px; right:10px; padding:25px 0px;}
# }
# </style>
# <!-- The overlay -->
# <div class="overlay boxShadow" id="myNav">
# <a class="closebtn" href="javascript:void(0)" onclick="closeNav()">×</a>
# <div class="overlay-content">
# <div class="menuLineBreak"></div>
# <a href="/">Home</a>
# <div class="menuLineBreak"></div>
# <a href="/countries-listing.php" title="Current military strength by country ranked from strongest to weakest">2026 Ranking</a>
# <div class="menuLineBreak"></div>
# <a href="/countries-comparison.php" title="Compare military strength of two countries side-by-side">Compare Countries</a>
# <div class="menuLineBreak"></div>
# <a href="/countries.php" title="GlobalFirepower.com countries list">Countries List</a>
# <div class="menuLineBreak"></div>
# <a href="/coalitions.php" title="GlobalFirepower.com coalitions builder">Coalitions Builder</a>
# <div class="menuLineBreak"></div>
# <a href="/global-ranks-previous.php" title="Previous global military rankings">Previous Rankings</a>
# <div class="menuLineBreak"></div>
# <a href="/aircraft-total.php" title="Current aircraft strength by country">Airpower</a>
# <div class="menuLineBreak"></div>
# <a href="/armor-tanks-total.php" title="Current tank strength by country">Land Forces</a>
# <div class="menuLineBreak"></div>
# <a href="/navy-ships.php" title="Current naval strength by country">Naval Forces</a>
# <div class="menuLineBreak"></div>
# <a href="https://www.worldwarnext.com/" target="_blank" title="An algorithmic approach to predicting the next great global conflict">World War Next</a>
# <div class="menuLineBreak"></div>
# </div>
# </div>
# <!--MAINMENU-->
# <div class="contentStripOuter" style="background-color:#fff;">
# <div class="contentStripInner" style="padding:25px 0px 15px 0px; text-align:center;">
# <script async="" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script><!-- GFP Sitewide Header -->
# <ins class="adsbygoogle" data-ad-client="ca-pub-5604186322601931" data-ad-format="auto" data-ad-slot="6798062608" data-full-width-responsive="true" style="display:block;"></ins>
# <script>(adsbygoogle = window.adsbygoogle || []).push({});</script>
# </div>
# </div>
# <!--SearchBlock-->
# <div class="contentStripOuter" style="background-color:#efefef;">
# <div style="width:75%; max-width:550px; display:inline-block; position:relative; padding:10px 0 0 0;">
# <script async="" src="https://cse.google.com/cse.js?cx=partner-pub-5604186322601931:1474208600"></script><div class="gcse-searchbox-only"></div>
# </div>
# </div>
# <!--SearchBlock-->
# <!--INTROSTRIP-->
# <div class="contentStripOuter" style="background-color:#fff;">
# <div class="contentStripInner" style="text-align:left;">
# <div class="leftColBlock">
# <h1 class="textJumbo"><span class="textBold">2026</span> Russia Military Strength</h1>
# <br/>
# <div style="width:200px; height:1px; background-color:#333; display:inline-block; position:relative; margin:15px 0px;"></div>
# <br/>
# <div style="width:auto; display:inline-block;">
# <img alt="Russia National flag graphic" loading="lazy" src="/imgs/flags/med/russia.jpg" style="width:55px; height:35px; margin:0px 0px 15px 0px;"/>
# </div>
# <br/>
# <span class="textNormal textDkGray">
#                             										The GFP index denotes Russia as a <span class="textBold">Top 5</span> global military power.<br/><br/>
#
#                             	For <span class="textBold">2026</span>, Russia is ranked <span class="textBold">2</span> of 145 out of the <a href="/countries.php" title="Countries included in GFP review">countries considered</a> for the <a href="/countries-listing.php" title="2026 military strength ranking">annual GFP review</a>. The nation holds a PwrIndx* score of <span class="textBold">0.0791</span> (a score of 0.0000 is considered 'perfect'). This entry last reviewed on <span class="textItalics">01/19/2026</span>.
#                              </span>
# <br/><br/>
# <span class="textSmall2 textDkGray">
#                                     	*PwrIndx: Each nation is assessed on individual and collective values processed through an in-house formula to generate its 'PwrIndx' (Power Index) score. Some values are estimated when official numbers are not available. View the NOTES tab below for a detailed breakdown of other assessments.
#                                     </span>
# </div>
# <div class="box rightColBlock">
# <img alt="Russia country map image" loading="lazy" src="/imgs/maps/med/russia.jpg" style="width:100%; max-width:600px;"/>
# </div>
# </div>
# </div>
# <!--INTROSTRIP-->
# <!--ADBLOCK-->
# <div style="width:100%; display:inline-block; position:relative; text-align:center; padding:25px;">
# <script async="" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script><!-- GFP Sitewide Level 1 -->
# <ins class="adsbygoogle" data-ad-client="ca-pub-5604186322601931" data-ad-format="auto" data-ad-slot="5305660472" style="display:block"></ins>
# <script>(adsbygoogle = window.adsbygoogle || []).push({});</script>
# </div>
# <!--ADBLOCK-->
# <!--NOTESOBSERVATIONS-->
# <div class="contentStripOuter" style="background-color:#efefef;">
# <div class="contentStripInner" style="text-align:center; padding:10px 25px;">
# <div style="width:100%; display:inline-block; position:relative; padding:10px 15px; background-color:#fff; text-align:left;">
# <span class="textDkGray textNormal">
# <span class="textBold">Notes:</span>
# <br/>
# 						As the No.2 global military power, the country continues to double-down in its efforts across eastern Ukraine despite American attempts at a permanent cease-fire. Western material support continues to aid Ukraine while global supporters of Russia - Venezuela and Syria in particular - are no longer viable assets. View the inventory breakdown of Russia at our partner site <a href="https://www.warpowerrussia.com" target="_blank" title="Russia Military by-the-numbers"><span class="textBold">Warpower:Russia</span></a>.</span>
# </div>
# </div>
# </div>
# <!--NOTESOBSERVATIONS-->
# <style>
# .dropbtn{background-color:#007bbf; color:#fff; padding:16px; font-size:16px; border:none; cursor:pointer;}
# .dropdown{position:relative; display:inline-block; float:right;}
# .dropdown-content{display:none; position:absolute; background-color:#f9f9f9; min-width:200px; box-shadow:0px 8px 16px 0px rgba(0,0,0,0.2); z-index:1; text-align:left; max-height:640px; overflow:auto;}
# .dropdown-content a{color:black; padding:12px 16px; text-decoration:none; display:block;}
# .dropdown-content a:hover{background-color:#f1f1f1}
# .dropdown:hover .dropdown-content{display:block;}
# .dropdown:hover .dropbtn{background-color:#0cf;}
# .ddFlagImg{width:30px; height:24px; display:inline-block; position:relative; margin:0 10px 0 0; float:left;}
# </style>
# <script src="/common/2025/loader.js"></script>
# <div class="contentStripOuter" style="background-color:#fff);">
# <div class="contentStripInner" style="text-align:left; padding:25px;">
# <div class="dropdown">
# <button class="dropbtn">Go-To Country</button>
# <div class="dropdown-content">
# <a href="/country-military-strength-detail.php?country_id=afghanistan"><img alt="Afghan national flag icon" class="ddFlagImg" src="/imgs/flags/sml/afghanistan.jpg"/>Afghanistan</a>
# <a href="/country-military-strength-detail.php?country_id=albania"><img alt="Albanian national flag icon" class="ddFlagImg" src="/imgs/flags/sml/albania.jpg"/>Albania</a>
# <a href="/country-military-strength-detail.php?country_id=algeria"><img alt="Algerian national flag icon" class="ddFlagImg" src="/imgs/flags/sml/algeria.jpg"/>Algeria</a>
# <a href="/country-military-strength-detail.php?country_id=angola"><img alt="Angolan national flag icon" class="ddFlagImg" src="/imgs/flags/sml/angola.jpg"/>Angola</a>
# <a href="/country-military-strength-detail.php?country_id=argentina"><img alt="Argentine national flag icon" class="ddFlagImg" src="/imgs/flags/sml/argentina.jpg"/>Argentina</a>
# <a href="/country-military-strength-detail.php?country_id=armenia"><img alt="Armenian national flag icon" class="ddFlagImg" src="/imgs/flags/sml/armenia.jpg"/>Armenia</a>
# <a href="/country-military-strength-detail.php?country_id=australia"><img alt="Australian national flag icon" class="ddFlagImg" src="/imgs/flags/sml/australia.jpg"/>Australia</a>
# <a href="/country-military-strength-detail.php?country_id=austria"><img alt="Austrian national flag icon" class="ddFlagImg" src="/imgs/flags/sml
><img alt="Myamar national flag icon" class="ddFlagImg" src="/imgs/flags/sml/vietnam.jpg"/>Vietnam</a>
# <a href="/country-military-strength-detail.php?country_id=yemen"><img alt="Myamar national flag icon" class="ddFlagImg" src="/imgs/flags/sml/yemen.jpg"/>Yemen</a>
# <a href="/country-military-strength-detail.php?country_id=zambia"><img alt="Myamar national flag icon" class="ddFlagImg" src="/imgs/flags/sml/zambia.jpg"/>Zambia</a>
# <a href="/country-military-strength-detail.php?country_id=zimbabwe"><img alt="Myamar national flag icon" class="ddFlagImg" src="/imgs/flags/sml/zimbabwe.jpg"/>Zimbabwe</a>
# </div>
# </div>
# <h2 class="textDkgray textLargest">Breakdown</h2>
# <br/>
# <div style="width:200px; height:1px; background-color:#fff; display:inline-block; position:relative; margin:15px 0px;"></div>
# <br/>
# <style>
# .collapsible{background-color:#777; color:white; cursor:pointer; padding:18px; width:100%; border:none; text-align:left; outline:none; font-size:18px;}
# .active, .collapsible:hover{background-color:#336699;}
# .contentSpecs{padding:0 18px 0 18px; max-height:0; overflow:hidden; transition:max-height 0.2s ease-out; background-color:#fff; border:1px solid #dfdfdf; text-align:center;}
# .specsFullContainers{width:100%; display:inline-block; position:relative; padding:10px 15px 10px 15px; margin:10px 3px 10px 3px; text-align:left;}
# .specsGenContainers{width:24%; display:inline-block; position:relative; padding:10px 15px 10px 15px; margin:10px 3px 10px 3px; text-align:left; border:1px solid #333; border-top:1px solid #CCC; vertical-align:top; background-image:linear-gradient(to bottom,#333,#000);}
# .specsRankBox{width:auto; display:inline-block; position:absolute; bottom:0; right:0; background-image:linear-gradient(to bottom,#333,#000); text-align:center; padding:0px 10px 0px 10px; border-top:1px solid #CCC; z-index:333;}
# .dividerLine{width:100%; height:4px; display:inline-block; position:relative; margin:10px 0px 15px 0px; background-color:#333;}
#
# @media only screen and (max-width:800px){
# 	.specsGenContainers{width:100%; border-right:none; border-bottom:thin solid #999;}
# }
# </style>
# <!--OVERVIEW-->
# <button class="collapsible">AT-A-GLANCE [+]</button>
# <div class="contentSpecs">
# <style>
# .graphContainer{width:100%; max-width:750px; margin-left:auto; margin-right:auto; padding:15px 2%; float:left; text-align:center;}
# .notesContainer{text-align:left; max-width:750px; padding:0px 2%; float:right;}
#
# @media only screen and (max-width:1600px){
# ...
# <a class="picTrans" href="/country-military-strength-detail.php?country_id=serbia" title="Details of current Serbia military strength"><img alt="National flag of Serbia" class="flagBlockStyling" loading="lazy" src="/imgs/flags/sml/serbia.jpg"/></a>
# <a class="picTrans" href="/country-military-strength-detail.php?country_id=singapore" title="Details of current Singapore military strength"><img alt="National flag of Singapore" class="flagBlockStyling" loading="lazy" src="/imgs/flags/sml/singapore.jpg"/></a>
# <a class="picTrans" href="/country-military-strength-detail.php?country_id=slovakia" title="Details of current Slovakia military strength"><img alt="National flag of Slovakia" class="flagBlockStyling" loading="lazy" src="/imgs/flags/sml/slovakia.jpg"/></a>
# <a class="picTrans" href="/country-military-strength-detail.php?country_id=slovenia" title="Details of current Slovenian military strength"><img alt="National flag of Slovenia" class="flagBlockStyling" loading="lazy" src="/imgs/flags/sml/slovenia.jpg"/></a>
# <a class="picTrans" href="/country-military-strength-detail.php?country_id=somalia" title="Details of current Somalian military strength"><img alt="National flag of Somalia" class="flagBlockStyling" loading="lazy" src="/imgs/flags/sml/somalia.jpg"/></a>
# <a class="picTrans" href="/country-military-strength-detail.php?country_id=south-africa" title="Details of current South Africa military strength"><img alt="National flag of South Africa" class="flagBlockStyling" loading="lazy" src="/imgs/flags/sml/south-africa.jpg"/></a>
# <a class="picTrans" href="/country-military-strength-detail.php?country_id=south-korea" title="Details of current South Korea military strength"><img alt="National flag of South Korea" class="flagBlockStyling" loading="lazy" src="/imgs/flags/sml/south-korea.jpg"/></a>
# <a class="picTrans" href="/country-military-strength-detail.php?country_id=south-sudan" title="Details of current South Sudanese military strength"><img alt="National flag of South Sudan" class="flagBlockStyling" loading="lazy" src="/imgs/flags/sml/south-sudan.jpg"/></a>
# <a class="picTrans" href="/country-military-strength-detail.php?country_id=spain" title="Details of current Spain military strength"><img alt="National flag of Spain" class="flagBlockStyling" loading="lazy" src="/imgs/flags/sml/spain.jpg"/></a>
# <a class="picTrans" href="/country-military-strength-detail.php?country_id=sweden" title="Details of current Sweden military strength"><img alt="National flag of Sweden" class="flagBlockStyling" loading="lazy" src="/imgs/flags/sml/sweden.jpg"/></a>
# <a class="picTrans" href="/country-military-strength-detail.php?country_id=switzerland" title="Details of current Switzerland military strength"><img alt="National flag of Switzerland" class="flagBlockStyling" loading="lazy" src="/imgs/flags/sml/switzerland.jpg"/></a>
# <a class="picTrans" href="/country-military-strength-detail.php?country_id=syria" title="Details of current Syria military strength"><img alt="National flag of Syria" class="flagBlockStyling" loading="lazy" src="/imgs/flags/sml/syria.jpg"/></a>
# <a class="picTrans" href="/country-military-strength-detail.php?country_id=taiwan" title="Details of current Taiwan military strength"><img alt="National flag of Taiwan" class="flagBlockStyling" loading="lazy" src="/imgs/flags/sml/taiwan.jpg"/></a>
# <a class="picTrans" href="/country-military-strength-detail.php?country_id=thailand" title="Details of current Thailand military strength"><img alt="National flag of Thailand" class="flagBlockStyling" loading="lazy" src="/imgs/flags/sml/thailand.jpg"/></a>
# <a class="picTrans" href="/country-military-strength-detail.php?country_id=tunisia" title="Details of current Tunisian military strength"><img alt="National flag of Tunisia" class="flagBlockStyling" loading="lazy" src="/imgs/flags/sml/tunisia.jpg"/></a>
# <a class="picTrans" href="/country-military-strength-detail.php?country_id=turkey" title="Details of current Turkey military strength"><img alt="National flag of Turkey" class="flagBlockStyling" loading="lazy" src="/imgs/flags/sml/turkey.jpg"/></a>
# <a class="picTrans" href="/country-military-strength-detail.php?country_id=turkmenistan" title="Details of current Turkmenistan military strength"><img alt="National flag of Turkmenistan" class="flagBlockStyling" loading="lazy" src="/imgs/flags/sml/turkmenistan.jpg"/></a>
# <a class="picTrans" href="/country-military-strength-detail.php?country_id=ukraine" title="Details of current Ukraine military strength"><img alt="National flag of Ukraine" class="flagBlockStyling" loading="lazy" src="/imgs/flags/sml/ukraine.jpg"/></a>
# <a class="picTrans" href="/country-military-strength-detail.php?country_id=united-arab-emirates" title="Details of current UAE military strength"><img alt="National flag of the United Arab Emirates" class="flagBlockStyling" loading="lazy" src="/imgs/flags/sml/united-arab-emirates.jpg"/></a>
# <a class="picTrans" href="/country-military-strength-detail.php?country_id=united-kingdom" title="Details of current United Kingdom military strength"><img alt="National flag of the United Kingdom (Britain)" class="flagBlockStyling" loading="lazy" src="/imgs/flags/sml/united-kingdom.jpg"/></a>
# <a class="picTrans" href="/country-military-strength-detail.php?country_id=united-states-of-america" title="Details of current United States military strength"><img alt="National flag of the United States" class="flagBlockStyling" loading="lazy" src="/imgs/flags/sml/united-states.jpg"/></a>
# <a class="picTrans" href="/country-military-strength-detail.php?country_id=uzbekistan" title="Details of current Uzbekistan military strength"><img alt="National flag of Uzbekistan" class="flagBlockStyling" loading="lazy" src="/imgs/flags/sml/uzbekistan.jpg"/></a>
# <a class="picTrans" href="/country-military-strength-detail.php?country_id=venezuela" title="Details of current Venezuela military strength"><img alt="National flag of Venezuela" class="flagBlockStyling" loading="lazy" src="/imgs/flags/sml/venezuela.jpg"/></a>
# <a class="picTrans" href="/country-military-strength-detail.php?country_id=vietnam" title="Details of current Vietnam military strength"><img alt="National flag of Vietnam" class="flagBlockStyling" loading="lazy" src="/imgs/flags/sml/vietnam.jpg"/></a>
# <a class="picTrans" href="/country-military-strength-detail.php?country_id=yemen" title="Details of current Yemen military strength"><img alt="National flag of Yemen" class="flagBlockStyling" loading="lazy" src="/imgs/flags/sml/yemen.jpg"/></a>
# </div>
# <br/><br/>
# <span class="textSmall2 textWhite">The GlobalFirepower.com logo is a trademark of this website and is protected by all applicable domestic and international intellectual property laws. The published content of the pages contained herein is unique to this website (unless where indicated) and not for reuse in any form. About: GlobalFirepower.com is an annually-updated, statistics-based website tracking defense-related information of 145 nations and exists as a wholly-independent resource. Part of the Military Factory network of sites that includes <a class="footerLink" href="https://www.militaryfactory.com" rel="noopener" target="_blank" title="Military Factory - Global Defense Reference">MilitaryFactory.com</a>, <a class="footerLink" href="https://www.wdmma.org" rel="noopener" target="_blank" title="WDMMA - The World Directory of Modern Military Aircraft">WDMMA.org</a>, and <a class="footerLink" href="https://www.wdmmw.org" rel="noopener" target="_blank" title="WDMMW - The World Directory of Modern Military Warships">WDMMW.org</a>. No A.I. was used in the generation of this content.</span>
# </div>
# </div>
# <style>
# .footerLinks{border:1px solid #666; padding:5px 10px; margin:5px 10px 0px 0px; display:inline-block; color:#fff;}
# .footerLinks:hover{border:1px solid #fc0; color:#fc0;}
# </style>
# <div class="contentStripOuter" style="background-color:#343434;">
# <div class="contentStripInner" style="text-align:left; padding:25px;">
# <a class="textSmall2" href="https://www.warpoweraustralia.com/" style="text-decoration:none;" target="_blank" title="Detailing the exact military strengths and weaknesses of the nation of Australia"><span class="footerLinks">Warpower Australia</span></a>
# <a class="textSmall2" href="https://www.warpowerbangladesh.com/" style="text-decoration:none;" target="_blank" title="Detailing the exact military strengths and weaknesses of the nation of Bangladesh"><span class="footerLinks">Warpower Bangladesh</span></a>
# <a class="textSmall2" href="https://www.warpowercanada.com/" style="text-decoration:none;" target="_blank" title="Detailing the exact military strengths and weaknesses of the nation of Canada"><span class="footerLinks">Warpower Canada</span></a>
# <a class="textSmall2" href="https://www.warpowerchina.com/" style="text-decoration:none;" target="_blank" title="Detailing the exact military strengths and weaknesses of the nation of China"><span class="footerLinks">Warpower China</span></a>
# <a class="textSmall2" href="https://www.warpoweregypt.com/" style="text-decoration:none;" target="_blank" title="Detailing the exact military strengths and weaknesses of the nation of Egypt"><span class="footerLinks">Warpower Egypt</span></a>
# <a class="textSmall2" href="https://www.warpowergermany.com/" style="text-decoration:none;" target="_blank" title="Detailing the exact military strengths and weaknesses of the nation of Germany"><span class="footerLinks">Warpower Germany</span></a>
# <a class="textSmall2" href="https://www.warpowergreece.com/" style="text-decoration:none;" target="_blank" title="Detailing the exact military strengths and weaknesses of the nation of Greece"><span class="footerLinks">Warpower Greece</span></a>
# <a class="textSmall2" href="https://www.warpowerindia.com/" style="text-decoration:none;" target="_blank" title="Detailing the exact military strengths and weaknesses of the nation of India"><span class="footerLinks">Warpower India</span></a>
# <a class="textSmall2" href="https://www.warpowerindonesia.com/" style="text-decoration:none;" target="_blank" title="Detailing the exact military strengths and weaknesses of the nation of Indonesia"><span class="footerLinks">Warpower Indonesia</span></a>
# <a class="textSmall2" href="https://www.warpoweriran.com/" style="text-decoration:none;" target="_blank" title="Detailing the exact military strengths and weaknesses of the nation of the Islamic Republic of Iran"><span class="footerLinks">Warpower Iran</span></a>
# <a class="textSmall2" href="https://www.warpowerisrael.com/" style="text-decoration:none;" target="_blank" title="Detailing the exact military strengths and weaknesses of the nation of Israel"><span class="footerLinks">Warpower Israel</span></a>
# <a class="textSmall2" href="https://www.warpowerjapan.com/" style="text-decoration:none;" target="_blank" title="Detailing the exact military strengths and weaknesses of the nation of Japan"><span class="footerLinks">Warpower Japan</span></a>
# <a class="textSmall2" href="https://www.warpowernorthkorea.com/" style="text-decoration:none;" target="_blank" title="Detailing the exact military strengths and weaknesses of the nation of North Korea"><span class="footerLinks">Warpower North Korea</span></a>
# <a class="textSmall2" href="https://www.warpowerpakistan.com/" style="text-decoration:none;" target="_blank" title="Detailing the exact military strengths and weaknesses of the nation of Pakistan"><span class="footerLinks">Warpower Pakistan</span></a>
# <a class="textSmall2" href="https://www.warpowerphilippines.com/" style="text-decoration:none;" target="_blank" title="Detailing the exact military strengths and weaknesses of the nation of the Philippines"><span class="footerLinks">Warpower Philippines</span></a>
# <a class="textSmall2" href="https://www.warpowerpoland.com/" style="text-decoration:none;" target="_blank" title="Detailing the exact military strengths and weaknesses of the nation of Poland"><span class="footerLinks">Warpower Poland</span></a>
# <a class="textSmall2" href="https://www.warpowerrussia.com/" style="text-decoration:none;" target="_blank" title="Detailing the exact military strengths and weaknesses of the nation of Russia"><span class="footerLinks">Warpower Russia</span></a>
# <a class="textSmall2" href="https://www.warpowersaudiarabia.com/" style="text-decoration:none;" target="_blank" title="Detailing the exact military strengths and weaknesses of the nation of the Kingdom of Saudi Arabia"><span class="footerLinks">Warpower Saudi Arabia</span></a>
# <a class="textSmall2" href="https://www.warpowersouthkorea.com/" style="text-decoration:none;" target="_blank" title="Detailing the exact military strengths and weaknesses of the nation of the Republic of Korea (South Korea)"><span class="footerLinks">Warpower South Korea</span></a>
# <a class="textSmall2" href="https://www.warpowertaiwan.com/" style="text-decoration:none;" target="_blank" title="Detailing the exact military strengths and weaknesses of the nation of Taiwan"><span class="footerLinks">Warpower Taiwan</span></a>
# <a class="textSmall2" href="https://www.warpowerturkey.com/" style="text-decoration:none;" target="_blank" title="Detailing the exact military strengths and weaknesses of the nation of Turkey"><span class="footerLinks">Warpower Turkiye</span></a>
# <a class="textSmall2" href="https://www.warpowerukraine.com/" style="text-decoration:none;" target="_blank" title="Detailing the exact military strengths and weaknesses of the nation of Ukraine"><span class="footerLinks">Warpower Ukraine</span></a>
# <a class="textSmall2" href="https://www.warpoweruk.com/" style="text-decoration:none;" target="_blank" title="Detailing the exact military strengths and weaknesses of the nation of the United Kingdom (Britain)"><span class="footerLinks">Warpower United Kingdom</span></a>
# <a class="textSmall2" href="https://www.warpowerus.com/" style="text-decoration:none;" target="_blank" title="Detailing the exact military strengths and weaknesses of the nation of the United States"><span class="footerLinks">Warpower United States</span></a>
# <a class="textSmall2" href="https://www.worldwarnext.com/" style="text-decoration:none;" target="_blank" title="An algorithmic approach to predicting the next World War"><span class="footerLinks">World War Next</span></a>
# <br/><br/>
# <span class="textSmall2 textLtGray">©2026 www.GlobalFirepower.com • All Rights Reserved • Content ©2006-2026 (20yrs)</span>
# </div>
# </div>
# <!--FOOTERSTRIP-->
# <!--COLLAPSELEMENTSCRIPT-->
# <script>
# var coll = document.getElementsByClassName("collapsible");
# var i;
#
# for (i = 0; i < coll.length; i++) {
#   coll[i].addEventListener("click", function() {
#     this.classList.toggle("active");
#     var content = this.nextElementSibling;
#     if (content.style.maxHeight){
#       content.style.maxHeight = null;
#     } else {
#       content.style.maxHeight = content.scrollHeight + "px";
#     }
#   });
# }
# </script>
# <script>(function(){function c(){var b=a.contentDocument||a.contentWindow.document;if(b){var d=b.createElement('script');d.innerHTML="window.__CF$cv$params={r:'9da269f38aa7b0ee',t:'MTc3MzE0NjY5OA=='};var a=document.createElement('script');a.src='/cdn-cgi/challenge-platform/scripts/jsd/main.js';document.getElementsByTagName('head')[0].appendChild(a);";b.getElementsByTagName('head')[0].appendChild(d)}}if(document.body){var a=document.createElement('iframe');a.height=1;a.width=1;a.style.position='absolute';a.style.top=0;a.style.left=0;a.style.border='none';a.style.visibility='hidden';document.body.appendChild(a);if('loading'!==document.readyState)c();else if(window.addEventListener)document.addEventListener('DOMContentLoaded',c);else{var e=document.onreadystatechange||function(){};document.onreadystatechange=function(b){e(b);'loading'!==document.readyState&&(document.onreadystatechange=e,c())}}}})();</script></body>
# </html>

# %%
#name
c_span = soup.find('h1')

country_text = c_span.get_text(strip=True)

country = country_text.replace("2026", "").replace("Military Strength", "").strip()

print(country)
# Out:
# Russia

# %%
#Top Rank
main_span = soup.find('span', class_='textNormal textDkGray')

f = main_span.find_all('span', class_='textBold')
#print(f)
top_rank_text = f[0].get_text(strip=True)
top_rank = top_rank_text.replace("Top", "").strip()
print(top_rank)
# Out:
# 5

# %%
#Rank
country_rank = f[2].get_text(strip=True)
print(country_rank)
# Out:
# 2

# %%
#PowerIndex
power_index_rank = f[3].get_text(strip=True)
print(power_index_rank)
# Out:
# 0.0791

# %%
#defense_budget
defence_span = soup.find_all('span', class_='textWhite textShadow')
# print(defence_span[2])
defence_budget = defence_span[2].text
print(defence_budget)
# print(defence_span)
# Out:
# $212,638,272,000 USD

# %%
#population
population_span = soup.find_all('span', class_='textLarge textWhite textShadow')
# print(population_span)

p_text=population_span[0].text
population = p_text.replace("Population: ", "").strip()
print(population)
# Out:
# 140,820,810

# %%
#available_manpower, active_personnel, reserve_personnel
manpower_span = soup.find_all('span', class_='textWhite textShadow')
# print(manpower_span)
manpower = manpower_span[8].text.strip()
active_personnels = manpower_span[12].text.strip()
reserve_personnel = manpower_span[13].text.strip()
paramilitory_personnel = manpower_span[14].text.strip()
airforce_personnel = manpower_span[15].text.strip()
army_personnel = manpower_span[16].text.strip()
navy_personnel = manpower_span[17].text.strip()

print(manpower)
print(active_personnels)
print(reserve_personnel)
print(paramilitory_personnel)
print(airforce_personnel)
print(army_personnel)
print(navy_personnel)
# Out:
# 69,002,197
# 1,320,000
# 2,000,000
# 250,000
# 203,376
# 600,000
# 160,000

# %%
#total aircraft
tair_span = soup.find_all('span', class_='textLarge textWhite textShadow')
# print(tair_span)

total_aircraft = tair_span[1].text.split("\n")[0]
total_aircraft = total_aircraft.replace("Stock: ", "").strip()
print(total_aircraft)
# Out:
# 4,237

# %%
#fighter_aircraft, tank
air_span = soup.find_all('span', class_='textWhite textShadow')
# print(air_span)
# print(air_span[27])

text = air_span[19].text

fighter_aircraft = text.split("\n")[0]          # take first line
fighter_aircraft = fighter_aircraft.split("(")[0]    # remove percentage
fighter_aircraft = fighter_aircraft.replace("Stock:", "").strip()
print(fighter_aircraft)

text = air_span[27].text
tank = text.split("\n")[0]          # take first line
tank = tank.split("(")[0]    # remove percentage
tank = tank.replace("Stock:", "").strip()
print(tank)
# Out:
# 861
# 5,630

# %%
#naval_assets
naval_span = soup.find_all('span', class_='textLarge textWhite textShadow')
naval_assets = naval_span[2].text
print(naval_assets)
# Out:
# 747

# %%
print("="*60)
print(f"        🇮🇳 {country} Military Overview")
print("="*60)

print("\n📊 Global Ranking")
print("-"*60)
print(f"Top Rank Category   : {top_rank}")
print(f"Country Rank        : {country_rank}")
print(f"Power Index Score   : {power_index_rank}")

print("\n💰 Defence & Population")
print("-"*60)
print(f"Defence Budget      : {defence_budget}")
print(f"Population          : {population}")

print("\n👥 Manpower")
print("-"*60)
print(f"Total Manpower      : {manpower}")
print(f"Active Personnel    : {active_personnels}")
print(f"Reserve Personnel   : {reserve_personnel}")
print(f"Paramilitary        : {paramilitory_personnel}")
print(f"Airforce Personnel  : {airforce_personnel}")
print(f"Army Personnel      : {army_personnel}")
print(f"Navy Personnel      : {navy_personnel}")

print("\n✈️  Air & Land Strength")
print("-"*60)
print(f"Total Aircraft      : {total_aircraft}")
print(f"Fighter Aircraft    : {fighter_aircraft}")
print(f"Tanks               : {tank}")

print("\n🚢 Naval Strength")
print("-"*60)
print(f"Total Naval Assets  : {naval_assets}")

print("\n" + "="*60)
# Out:
# ============================================================
#         🇮🇳 Russia Military Overview
# ============================================================
#
# 📊 Global Ranking
# ------------------------------------------------------------
# Top Rank Category   : 5
# Country Rank        : 2
# Power Index Score   : 0.0791
#
# 💰 Defence & Population
# ------------------------------------------------------------
# Defence Budget      : $212,638,272,000 USD
# Population          : 140,820,810
#
# 👥 Manpower
# ------------------------------------------------------------
# Total Manpower      : 69,002,197
# Active Personnel    : 1,320,000
# Reserve Personnel   : 2,000,000
# Paramilitary        : 250,000
# Airforce Personnel  : 203,376
# Army Personnel      : 600,000
# Navy Personnel      : 160,000
#
# ✈️  Air & Land Strength
# ------------------------------------------------------------
# Total Aircraft      : 4,237
# Fighter Aircraft    : 861
# Tanks               : 5,630
#
# 🚢 Naval Strength
# ------------------------------------------------------------
# Total Naval Assets  : 747
#
# ============================================================

# %% [markdown]
# #  Automate Scraping

# %%
#final full script
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

# Function to scrape a single metric
def scrape_metric(url, column_name):
    try:
        page = requests.get(url)
        soup = BeautifulSoup(page.text, "html.parser")

        data = []

        country_codes = soup.find_all('div', class_='shortFormName')
        values = soup.find_all('div', class_='valueContainer')

        for i in range(len(country_codes)):
            code = country_codes[i].text.strip()
            value = values[i].text.strip()

            data.append({
                "Country_Code": code,
                column_name: value
            })

        return pd.DataFrame(data)

    except Exception as e:
        print(f"Error scraping {column_name}: {e}")
        return pd.DataFrame()

# Base URL
base_url = 'https://www.globalfirepower.com/countries-listing.php'

# Scrape base URL for country names
print("Scraping country names...")
page = requests.get(base_url)
soup = BeautifulSoup(page.text, "html.parser")

name_span = soup.find_all('span', class_='textWhite textLarge textShadow')

data = []
for i in range(0, len(name_span)-1, 2):
    full_name = name_span[i].text.strip()
    short_name = name_span[i+1].text.strip()

    data.append({
        "Country_Code": short_name,
        "Country_Name": full_name
    })

# Create main DataFrame
df_final = pd.DataFrame(data)
print(f"Found {len(df_final)} countries\n")

# Dictionary of other sources
other_sources = {
    'https://www.globalfirepower.com/total-population-by-country.php': 'total_population',
    'https://www.globalfirepower.com/available-military-manpower.php': 'total_military_manpower',
    'https://www.globalfirepower.com/manpower-fit-for-military-service.php': 'fit_for_service',
    'https://www.globalfirepower.com/manpower-reaching-military-age-annually.php': 'population_reaching_military_age_annually',
    'https://www.globalfirepower.com/active-military-manpower.php': 'active_personnel',
    'https://www.globalfirepower.com/active-reserve-military-manpower.php': 'reserve_personnel',
    'https://www.globalfirepower.com/manpower-paramilitary.php': 'paramilitary',
    'https://www.globalfirepower.com/aircraft-total.php': 'total_military_aircraft',
    'https://www.globalfirepower.com/aircraft-total-fighters.php': 'fighter_aircraft',
    'https://www.globalfirepower.com/aircraft-total-attack-types.php': 'attack_aircraft',
    'https://www.globalfirepower.com/aircraft-total-transports.php': 'transport_aircraft',
    'https://www.globalfirepower.com/aircraft-total-trainers.php': 'trainer_aircraft',
    'https://www.globalfirepower.com/aircraft-total-special-mission.php': 'special_mission_aircraft',
    'https://www.globalfirepower.com/aircraft-total-tanker-fleet.php': 'tanker_aircraft',
    'https://www.globalfirepower.com/aircraft-helicopters-total.php': 'total_military_helicopters',
    'https://www.globalfirepower.com/aircraft-helicopters-attack.php': 'attack_helicopters',
    'https://www.globalfirepower.com/armor-tanks-total.php': 'tanks',
    'https://www.globalfirepower.com/armor-apc-total.php': 'armored_fighting_vehicles',
    'https://www.globalfirepower.com/armor-self-propelled-guns-total.php': 'self_propelled_artillery',
    'https://www.globalfirepower.com/armor-towed-artillery-total.php': 'towed_artillery',
    'https://www.globalfirepower.com/armor-mlrs-total.php': 'rocket_projectors',
    'https://www.globalfirepower.com/navy-ships.php': 'total_naval_fleet',
    'https://www.globalfirepower.com/navy-force-by-tonnage.php': 'total_naval_fleet_tonnage_mt',
    'https://www.globalfirepower.com/navy-aircraft-carriers.php': 'aircraft_carriers',
    'https://www.globalfirepower.com/navy-helo-carriers.php': 'helicopter_carriers',
    'https://www.globalfirepower.com/navy-submarines.php': 'submarines',
    'https://www.globalfirepower.com/navy-destroyers.php': 'destroyers',
    'https://www.globalfirepower.com/navy-frigates.php': 'frigates',
    'https://www.globalfirepower.com/navy-corvettes.php': 'corvettes',
    'https://www.globalfirepower.com/navy-patrol-coastal-craft.php': 'coastal_patrol_craft',
    'https://www.globalfirepower.com/navy-mine-warfare-craft.php': 'mine_warfare_craft',
    'https://www.globalfirepower.com/defense-spending-budget.php': 'defense_budget_usd',
    'https://www.globalfirepower.com/external-debt-by-country.php': 'external_debt_usd',
    'https://www.globalfirepower.com/purchasing-power-parity.php': 'purchasing_power_parity_usd',
    'https://www.globalfirepower.com/reserves-of-foreign-exchange-and-gold.php': 'foreign_exchange_and_gold_reserves_usd',
    'https://www.globalfirepower.com/major-serviceable-airports-by-country.php': 'total_serviceable_airports',
    'https://www.globalfirepower.com/labor-force-by-country.php': 'labour_force',
    'https://www.globalfirepower.com/major-ports-and-terminals.php': 'major_ports_and_terminals',
    'https://www.globalfirepower.com/merchant-marine-strength-by-country.php': 'total_merchant_marine_fleet',
    'https://www.globalfirepower.com/railway-coverage.php': 'railway_coverage_km',
    'https://www.globalfirepower.com/roadway-coverage.php': 'roadway_coverage_km',
    'https://www.globalfirepower.com/oil-production-by-country.php': 'oil_production_bbl',
    'https://www.globalfirepower.com/oil-consumption-by-country.php': 'oil_consumption_bbl',
    'https://www.globalfirepower.com/proven-oil-reserves-by-country.php': 'proven_oil_reserves_bbl',
    'https://www.globalfirepower.com/natural-gas-production-by-country.php': 'natural_gas_production_cum',
    'https://www.globalfirepower.com/natural-gas-consumption-by-country.php': 'natural_gas_consumption_cum',
    'https://www.globalfirepower.com/proven-natural-gas-reserves-by-country.php': 'proven_natural_gas_reserves_cum',
    'https://www.globalfirepower.com/coal-production-by-country.php': 'coal_production_cum',
    'https://www.globalfirepower.com/coal-consumption-by-country.php': 'coal_consumption_mt',
    'https://www.globalfirepower.com/proven-coal-reserves-by-country.php': 'proven_coal_reserves_cum',
    'https://www.globalfirepower.com/square-land-area.php': 'total_land_area_sq_km',
    'https://www.globalfirepower.com/coastline-coverage.php': 'coastline_coverage_km',
    'https://www.globalfirepower.com/border-coverage.php': 'border_coverage_km',
    'https://www.globalfirepower.com/waterway-coverage.php': 'waterway_coverage_km'
}

print(f"Total URLs to scrape: {len(other_sources)}\n")

# Loop through other_sources and scrape each URL
counter = 1
for url, column_name in other_sources.items():
    print(f"Scraping {counter}/{len(other_sources)}: {column_name}...")

    # Scrape the metric
    df_temp = scrape_metric(url, column_name)

    # Merge if data was scraped successfully
    if not df_temp.empty:
        df_final = df_final.merge(df_temp, on='Country_Code', how='left')
        print(f"  ✓ Added {column_name}")
    else:
        print(f"  ✗ Failed to scrape {column_name}")

    # Add delay between requests
    time.sleep(1)
    counter = counter + 1

# Display results
print(f"\n{'='*50}")
print(f"Scraping complete!")
print(f"Final DataFrame shape: {df_final.shape}")
print(f"Columns: {df_final.shape[1]}")
print(f"{'='*50}\n")

print("First few rows:")
print(df_final.head())

# Save to CSV
output_file = 'Military_raw_data.csv'
df_final.to_csv(output_file, index=False)
print(f"\nData saved to '{output_file}'")
# Out:
# Scraping country names...
# Found 145 countries
#
# Total URLs to scrape: 54
#
# Scraping 1/54: total_population...
#   ✓ Added total_population
# Scraping 2/54: total_military_manpower...
#   ✓ Added total_military_manpower
# Scraping 3/54: fit_for_service...
#   ✓ Added fit_for_service
# Scraping 4/54: population_reaching_military_age_annually...
#   ✓ Added population_reaching_military_age_annually
# Scraping 5/54: active_personnel...
#   ✓ Added active_personnel
# Scraping 6/54: reserve_personnel...
#   ✓ Added reserve_personnel
# Scraping 7/54: paramilitary...
#   ✓ Added paramilitary
# Scraping 8/54: total_military_aircraft...
#   ✓ Added total_military_aircraft
# Scraping 9/54: fighter_aircraft...
#   ✓ Added fighter_aircraft
# Scraping 10/54: attack_aircraft...
#   ✓ Added attack_aircraft
# Scraping 11/54: transport_aircraft...
#   ✓ Added transport_aircraft
# Scraping 12/54: trainer_aircraft...
#   ✓ Added trainer_aircraft
# Scraping 13/54: special_mission_aircraft...
#   ✓ Added special_mission_aircraft
# Scraping 14/54: tanker_aircraft...
#   ✓ Added tanker_aircraft
# Scraping 15/54: total_military_helicopters...
#   ✓ Added total_military_helicopters
# Scraping 16/54: attack_helicopters...
#   ✓ Added attack_helicopters
# Scraping 17/54: tanks...
#   ✓ Added tanks
# Scraping 18/54: armored_fighting_vehicles...
#   ✓ Added armored_fighting_vehicles
# Scraping 19/54: self_propelled_artillery...
#   ✓ Added self_propelled_artillery
# Scraping 20/54: towed_artillery...
#   ✓ Added towed_artillery
# Scraping 21/54: rocket_projectors...
#   ✓ Added rocket_projectors
# Scraping 22/54: total_naval_fleet...
#   ✓ Added total_naval_fleet
# Scraping 23/54: total_naval_fleet_tonnage_mt...
#   ✓ Added total_naval_fleet_tonnage_mt
# Scraping 24/54: aircraft_carriers...
#   ✓ Added aircraft_carriers
# Scraping 25/54: helicopter_carriers...
#   ✓ Added helicopter_carriers
# Scraping 26/54: submarines...
#   ✓ Added submarines
# Scraping 27/54: destroyers...
#   ✓ Added destroyers
# Scraping 28/54: frigates...
#   ✓ Added frigates
# Scraping 29/54: corvettes...
#   ✓ Added corvettes
# Scraping 30/54: coastal_patrol_craft...
#   ✓ Added coastal_patrol_craft
# Scraping 31/54: mine_warfare_craft...
#   ✓ Added mine_warfare_craft
# Scraping 32/54: defense_budget_usd...
#   ✓ Added defense_budget_usd
# Scraping 33/54: external_debt_usd...
#   ✓ Added external_debt_usd
# Scraping 34/54: purchasing_power_parity_usd...
#   ✓ Added purchasing_power_parity_usd
# Scraping 35/54: foreign_exchange_and_gold_reserves_usd...
#   ✓ Added foreign_exchange_and_gold_reserves_usd
# Scraping 36/54: total_serviceable_airports...
#   ✓ Added total_serviceable_airports
# Scraping 37/54: labour_force...
#   ✓ Added labour_force
# Scraping 38/54: major_ports_and_terminals...
#   ✓ Added major_ports_and_terminals
# Scraping 39/54: total_merchant_marine_fleet...
#   ✓ Added total_merchant_marine_fleet
# Scraping 40/54: railway_coverage_km...
#   ✓ Added railway_coverage_km
# Scraping 41/54: roadway_coverage_km...
#   ✓ Added roadway_coverage_km
# Scraping 42/54: oil_production_bbl...
#   ✓ Added oil_production_bbl
# Scraping 43/54: oil_consumption_bbl...
#   ✓ Added oil_consumption_bbl
# Scraping 44/54: proven_oil_reserves_bbl...
#   ✓ Added proven_oil_reserves_bbl
# Scraping 45/54: natural_gas_production_cum...
#   ✓ Added natural_gas_production_cum
# Scraping 46/54: natural_gas_consumption_cum...
#   ✓ Added natural_gas_consumption_cum
# Scraping 47/54: proven_natural_gas_reserves_cum...
#   ✓ Added proven_natural_gas_reserves_cum
# Scraping 48/54: coal_production_cum...
#   ✓ Added coal_production_cum
# Scraping 49/54: coal_consumption_mt...
#   ✓ Added coal_consumption_mt
# Scraping 50/54: proven_coal_reserves_cum...
#   ✓ Added proven_coal_reserves_cum
# Scraping 51/54: total_land_area_sq_km...
#   ✓ Added total_land_area_sq_km
# Scraping 52/54: coastline_coverage_km...
#   ✓ Added coastline_coverage_km
# Scraping 53/54: border_coverage_km...
#   ✓ Added border_coverage_km
# Scraping 54/54: waterway_coverage_km...
#   ✓ Added waterway_coverage_km
#
# ==================================================
# Scraping complete!
# Final DataFrame shape: (145, 56)
# Columns: 56
# ==================================================
#
# First few rows:
#   Country_Code   Country_Name total_population total_military_manpower  \
# 0          USA  United States      341,963,408             150,463,900
# 1          RUS         Russia      140,820,810              69,002,197
# 2          CHN          China    1,415,043,270             764,123,366
# 3          IND          India    1,409,128,296             662,290,299
# 4          SKO    South Korea       52,081,799              26,040,900
#
#   fit_for_service population_reaching_military_age_annually active_personnel  \
# 0     124,816,644                                 4,445,524        1,333,030
# 1      46,189,226                                 1,267,387        1,320,000
# 2     626,864,169                                19,810,606        2,035,000
# 3     522,786,598                                23,955,181        1,431,000
# 4      21,353,538                                   416,654          450,000
#
#   reserve_personnel paramilitary total_military_aircraft  ...  \
# 0           799,500            0                  13,032  ...
# 1         2,000,000      250,000                   4,237  ...
# 2           510,000      625,000                   3,529  ...
# 3         1,000,000    2,527,000                   2,183  ...
# 4         3,100,000      120,000                   1,540  ...
#
#                           natural_gas_production_cum  \
# 0  1,029,000,000,000                        \t\t\...
# 1  617,830,000,000                        \t\t\t\...
# 2  225,341,000,000                        \t\t\t\...
# 3  33,170,000,000                        \t\t\t\t...
# 4  55,127,000                        \t\t\t\t\t\t...
#
#                          natural_gas_consumption_cum  \
# 0  914,301,000,000                        \t\t\t\...
# 1  472,239,000,000                        \t\t\t\...
# 2  366,160,000,000                        \t\t\t\...
# 3  58,867,000,000                        \t\t\t\t...
# 4  59,480,000,000                        \t\t\t\t...
#
#                      proven_natural_gas_reserves_cum  \
# 0  13,402,000,000,000                        \t\t...
# 1  47,805,000,000,000                        \t\t...
# 2  6,654,000,000,000                        \t\t\...
# 3  1,381,000,000,000                        \t\t\...
# 4  7,079,000,000                        \t\t\t\t\...
#
#                                  coal_production_cum  \
# 0  534,234,000                        \t\t\t\t\t\...
# 1  531,130,000                        \t\t\t\t\t\...
# 2  4,805,000,000                        \t\t\t\t\...
# 3  1,020,000,000                        \t\t\t\t\...
# 4  16,081,000                        \t\t\t\t\t\t...
#
#                                  coal_consumption_mt  \
# 0  495,156,000                        \t\t\t\t\t\...
# 1  290,763,000                        \t\t\t\t\t\...
# 2  5,191,000,000                        \t\t\t\t\...
# 3  1,262,000,000                        \t\t\t\t\...
# 4  136,817,000                        \t\t\t\t\t\...
#
#                             proven_coal_reserves_cum  \
# 0  247,883,000,000                        \t\t\t\...
# 1  162,166,000,000                        \t\t\t\...
# 2  157,041,000,000                        \t\t\t\...
# 3  127,727,000,000                        \t\t\t\...
# 4  326,000,000                        \t\t\t\t\t\...
#
#                                total_land_area_sq_km  \
# 0  9,833,517                        \t\t\t\t\t\t\...
# 1  17,098,242                        \t\t\t\t\t\t...
# 2  9,596,960                        \t\t\t\t\t\t\...
# 3  3,287,263                        \t\t\t\t\t\t\...
# 4  99,720                        \t\t\t\t\t\t\r\n...
#
#                                coastline_coverage_km  \
# 0  19,924                        \t\t\t\t\t\t\r\n...
# 1  37,653                        \t\t\t\t\t\t\r\n...
# 2  14,500                        \t\t\t\t\t\t\r\n...
# 3  7,000                        \t\t\t\t\t\t\r\n\...
# 4  2,413                        \t\t\t\t\t\t\r\n\...
#
#                                   border_coverage_km  \
# 0  12,002                        \t\t\t\t\t\t\r\n...
# 1  22,407                        \t\t\t\t\t\t\r\n...
# 2  22,457                        \t\t\t\t\t\t\r\n...
# 3  13,888                        \t\t\t\t\t\t\r\n...
# 4  237                        \t\t\t\t\t\t\r\n\t\...
#
#                                 waterway_coverage_km
# 0  41,009                        \t\t\t\t\t\t\r\n...
# 1  102,000                        \t\t\t\t\t\t\r\...
# 2  27,700                        \t\t\t\t\t\t\r\n...
# 3  14,500                        \t\t\t\t\t\t\r\n...
# 4  1,600                        \t\t\t\t\t\t\r\n\...
#
# [5 rows x 56 columns]
#
# Data saved to 'Military_raw_data.csv'
